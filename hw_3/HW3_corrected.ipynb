# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/train.csv') #считываем файл

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Посчитайте процент выживаемости у каждого класса пассажиров (Pclass)
df.groupby("Pclass")["Survived"].mean() * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
#Выведите самое популярное мужское и самое популярное женское имя на корабле
def first_name_only(full_name):
  if "Mrs." in full_name:
    female_part = full_name.split("(")
    if len(female_part)>1:
      first_name=female_part[1].split()[0]
      return first_name
  name_part = full_name.split(",")[1].strip()
  first_name = name_part.split()[1]
  return first_name

# %%
df['FirstNameOnly']= df['Name'].apply(first_name_only)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked FirstNameOnly
# 0      0         A/5 21171   7.2500   NaN        S          Owen
# 1      0          PC 17599  71.2833   C85        C      Florence
# 2      0  STON/O2. 3101282   7.9250   NaN        S         Laina
# ...

# %%
male_names = df[df['Sex'] == 'male']['FirstNameOnly']
most_common_male_name = male_names.value_counts()

# Выделим самое популярное имя среди женщин
female_names = df[df['Sex'] == 'female']['FirstNameOnly']
most_common_female_name = female_names.value_counts()

# Выведем результаты
print(f"Самое популярное мужское имя: {most_common_male_name}")
print(f"Самое популярное женское имя: {most_common_female_name}")
# Out:
# Самое популярное мужское имя: FirstNameOnly
# William    35
# John       25
# George     14
# Charles    13
# Thomas     13
#            ..
# Ignjac      1
# Yoto        1
# Austen      1
# Mitto       1
# Juozas      1
# Name: count, Length: 287, dtype: int64
# Самое популярное женское имя: FirstNameOnly
# Anna          14
# Mary          13
# Elizabeth     11
# Margaret      10
# Alice          7
#               ..
# Laura          1
# Helmina        1
# Miriam         1
# Margaretta     1
# Gerda          1
# Name: count, Length: 186, dtype: int64

# %%
df.groupby(["Sex"])["FirstNameOnly"].describe()
# Out:
#        count unique      top freq
# Sex
# female   314    186     Anna   14
# male     577    287  William   35

# %%
#Выведите самое популярное мужское и самое популярное женское имя на корабле в каждом классе
df.groupby(["Sex", "Pclass"])["FirstNameOnly"].describe()
# Out:
#               count unique        top freq
# Sex    Pclass
# female 1         94     66  Elizabeth    5
#        2         76     56  Elizabeth    5
#        3        144    106       Anna    9
# male   1        122     66    William   11
#        2        108     60    William    9
#        3        347    222    William   15

# %%
#Выведите часть таблицы с пассажирами, возраст которых больше 44 лет
df[df['Age'] > 44]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 52            53         1       1
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Выведите часть таблицы с пассажирами, возраст которых меньше 44 лет и которые мужского пола
df[(df['Age'] > 44) & (df['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# 92            93         0       1     Chaffee, Mr. Herbert Fuller  male
# ..           ...       ...     ...                             ...   ...
# 771          772         0       3         Jensen, Mr. Niels Peder  male
# 789          790         0       1        Guggenheim, Mr. Benjamin  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch       Ticket     Fare    Cabin Embarked FirstNameOnly
# ...

# %%
#Выведите количества n-местных кабин (в которых было 2, 3, 4, ... человека)
df_cabins=df[(df['SibSp']+df['Parch'])>0]
df_cabins['PassengersInACabin']= df_cabins['Parch'] + df_cabins['SibSp'] #не учитывает самого пассажира, поэтому чтобы вычислить количество мест в каюте нужно добавить 1
df_cabins.head(5)
# Out:
# <ipython-input-40-03f7cc911870>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cabins['PassengersInACabin']= df_cabins['Parch'] + df_cabins['SibSp'] #не учитывает самого пассажира, поэтому чтобы вычислить количество мест в каюте нужно добавить 1
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 3            4         1       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df_cabins['CabinSize']= df_cabins['PassengersInACabin'] + 1
df_cabins.head(5)
# Out:
# <ipython-input-41-56a664e8393c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cabins['CabinSize']= df_cabins['PassengersInACabin'] + 1
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 3            4         1       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
df_cabins['CabinSize'].value_counts()
# Out:
# CabinSize
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64
